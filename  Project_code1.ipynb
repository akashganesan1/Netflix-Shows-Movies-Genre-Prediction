# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv(r"P:\Data mining\Project\Data\netflix_titles.csv")
data
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# # Data Cleaning

# %%
data = data.dropna()
data = data.reset_index(drop=True)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data['cast'] = data['cast'].str.split(',')

# %%
df_temp = pd.DataFrame(data['cast'].tolist()).fillna('').add_prefix('cast_')

# %%
data = pd.concat([data, df_temp], axis=1)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332 entries, 0 to 5331
# Data columns (total 56 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
#  12  cast_0        5332 non-null   object
#  13  cast_1        5332 non-null   object
#  14  cast_2        5332 non-null   object
#  15  cast_3        5332 non-null   object
#  16  cast_4        5332 non-null   object
#  17  cast_5        5332 non-null   object
# ...

# %%
data['cast_6']
# Out:
# 0          Reggie Carter
# 1
# 2          Laura Harrier
# 3         Victor Boccard
# 4
#               ...
# 5327
# 5328         Donal Logue
# 5329          Derek Graf
# 5330     Spencer Breslin
# 5331      Anita Shabdish
# Name: cast_6, Length: 5332, dtype: object

# %%
data = data.dropna()
data = data.reset_index(drop=True)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.drop(data.iloc[:,21:],inplace=True, axis=1)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332 entries, 0 to 5331
# Data columns (total 21 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
#  12  cast_0        5332 non-null   object
#  13  cast_1        5332 non-null   object
#  14  cast_2        5332 non-null   object
#  15  cast_3        5332 non-null   object
#  16  cast_4        5332 non-null   object
#  17  cast_5        5332 non-null   object
# ...

# %%
data['listed_in'] = data['listed_in'].str.split(',')

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
df_temp = pd.DataFrame(data['listed_in'].tolist()).add_prefix('genre_')

# %%
data = pd.concat([data, df_temp], axis=1)

# %%
data
# Out:
#      show_id     type                          title             director  \
# 0         s8    Movie                        Sankofa         Haile Gerima
# 1         s9  TV Show  The Great British Baking Show      Andy Devonshire
# 2        s10    Movie                   The Starling       Theodore Melfi
# 3        s13    Movie                   Je Suis Karl  Christian Schwochow
# 4        s25    Movie                          Jeans           S. Shankar
# ...      ...      ...                            ...                  ...
# 5327   s8802    Movie                        Zinzana      Majid Al Ansari
# 5328   s8803    Movie                         Zodiac        David Fincher
# 5329   s8805    Movie                     Zombieland      Ruben Fleischer
# 5330   s8806    Movie                           Zoom         Peter Hewitt
# 5331   s8807    Movie                         Zubaan          Mozez Singh
#
#                                                    cast  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5332 entries, 0 to 5331
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       5332 non-null   object
#  1   type          5332 non-null   object
#  2   title         5332 non-null   object
#  3   director      5332 non-null   object
#  4   cast          5332 non-null   object
#  5   country       5332 non-null   object
#  6   date_added    5332 non-null   object
#  7   release_year  5332 non-null   int64
#  8   rating        5332 non-null   object
#  9   duration      5332 non-null   object
#  10  listed_in     5332 non-null   object
#  11  description   5332 non-null   object
#  12  cast_0        5332 non-null   object
#  13  cast_1        5332 non-null   object
#  14  cast_2        5332 non-null   object
#  15  cast_3        5332 non-null   object
#  16  cast_4        5332 non-null   object
#  17  cast_5        5332 non-null   object
# ...

# %%
data = data.dropna()
data = data.reset_index(drop=True)

# %%
data
# Out:
#      show_id   type     title                 director  \
# 0         s8  Movie   Sankofa             Haile Gerima
# 1        s25  Movie     Jeans               S. Shankar
# 2        s42  Movie      Jaws         Steven Spielberg
# 3        s43  Movie    Jaws 2           Jeannot Szwarc
# 4        s44  Movie    Jaws 3                Joe Alves
# ...      ...    ...       ...                      ...
# 2290   s8795  Movie    اشتباك             Mohamed Diab
# 2291   s8799  Movie  Zed Plus  Chandra Prakash Dwivedi
# 2292   s8802  Movie   Zinzana          Majid Al Ansari
# 2293   s8803  Movie    Zodiac            David Fincher
# 2294   s8807  Movie    Zubaan              Mozez Singh
#
#                                                    cast  \
# 0     [Kofi Ghanaba,  Oyafunmike Ogunlano,  Alexandr...
# 1     [Prashanth,  Aishwarya Rai Bachchan,  Sri Laks...
# 2     [Roy Scheider,  Robert Shaw,  Richard Dreyfuss...
# 3     [Roy Scheider,  Lorraine Gary,  Murray Hamilto...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2295 entries, 0 to 2294
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       2295 non-null   object
#  1   type          2295 non-null   object
#  2   title         2295 non-null   object
#  3   director      2295 non-null   object
#  4   cast          2295 non-null   object
#  5   country       2295 non-null   object
#  6   date_added    2295 non-null   object
#  7   release_year  2295 non-null   int64
#  8   rating        2295 non-null   object
#  9   duration      2295 non-null   object
#  10  listed_in     2295 non-null   object
#  11  description   2295 non-null   object
#  12  cast_0        2295 non-null   object
#  13  cast_1        2295 non-null   object
#  14  cast_2        2295 non-null   object
#  15  cast_3        2295 non-null   object
#  16  cast_4        2295 non-null   object
#  17  cast_5        2295 non-null   object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['director'] = le.fit_transform(data['director'])

# %%
data['type'] = le.fit_transform(data['type'])

# %%
data['cast_0'] = le.fit_transform(data['cast_0'])
data['cast_1'] = le.fit_transform(data['cast_1'])
data['cast_2'] = le.fit_transform(data['cast_2'])
data['cast_3'] = le.fit_transform(data['cast_3'])
data['cast_4'] = le.fit_transform(data['cast_4'])
data['cast_5'] = le.fit_transform(data['cast_5'])
data['cast_6'] = le.fit_transform(data['cast_6'])

# %%
data['cast_7'] = le.fit_transform(data['cast_7'])
data['cast_8'] = le.fit_transform(data['cast_8'])
data['genre_0'] = le.fit_transform(data['genre_0'])
data['genre_1'] = le.fit_transform(data['genre_1'])
data['genre_2'] = le.fit_transform(data['genre_2'])
data['rating'] = le.fit_transform(data['rating'])
data['country'] = le.fit_transform(data['country'])

# %%
data_new = data[['type','director','country','rating','cast_0','cast_1','cast_2','cast_3','cast_4','cast_5','cast_6','cast_7','cast_8','genre_0','genre_1','genre_2']]

# %%
data_rating1 = data_new[data_new['rating'] == 8]

# %%
data_rating1
# Out:
#       type  director  country  rating  cast_0  cast_1  cast_2  cast_3  cast_4  \
# 0        0       580      291       8     854    1316      72    1265    1218
# 18       0       671      170       8     502     211     354    1952     262
# 26       0      1532        8       8     726    1020     620    1220     585
# 30       0      1245      100       8    1087    1603    1678     714     337
# 35       1       861      170       8    1513    1774    1468     511    1764
# ...    ...       ...      ...     ...     ...     ...     ...     ...     ...
# 2269     0       437      281       8    1057       0       0       0       0
# 2275     0       393      281       8     253     758     842     994     500
# 2278     0      1137      109       8     148     201       3    1176    1351
# 2291     0       302      109       8      22    1198     896    1565     126
# 2292     0       992      243       8      77    1525    1908      74    1081
#
# ...

# %%
data_new
# Out:
#       type  director  country  rating  cast_0  cast_1  cast_2  cast_3  cast_4  \
# 0        0       580      291       8     854    1316      72    1265    1218
# 1        0      1461      109       6    1263      44    1707    1236       0
# 2        0      1627      281       3    1393    1484    1463    1031    1216
# 3        0       720      281       3    1393    1008    1228     854     759
# 4        0       750      281       3     376     246    1675    1036     806
# ...    ...       ...      ...     ...     ...     ...     ...     ...     ...
# 2290     0      1114       63       6    1152     635    1769      32      44
# 2291     0       302      109       8      22    1198     896    1565     126
# 2292     0       992      243       8      77    1525    1908      74    1081
# 2293     0       392      281       5    1012     721    1485     153     271
# 2294     0      1126      109       6    1657    1568    1384    1081    1147
#
# ...

# %% [markdown]
# # MODULE TRAINING

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

# %%
X = data_rating1[['type','director','country','rating','cast_0','cast_1','cast_2','cast_3','cast_4','cast_5','cast_6','cast_7','cast_8','genre_0','genre_1']]

# %%
Y = data_rating1['genre_2']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.20)

# %%
clf = RandomForestClassifier(n_estimators = 100)  
  
# Training the model on the training dataset
# fit function is used to train the model using the training sets as parameters
clf.fit(X_train, y_train)
  
# performing predictions on the test dataset
y_pred = clf.predict(X_test)
  
# metrics are used to find accuracy or error
from sklearn import metrics  
print()
  
# using metrics module for accuracy calculation
print("ACCURACY OF THE MODEL: ", metrics.accuracy_score(y_test, y_pred))
# Out:
# ACCURACY OF THE MODEL:  0.6946107784431138

# %% [markdown]
# # decision tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn import tree

# %%
clf = DecisionTreeClassifier()

# Train Decision Tree Classifer
clf = clf.fit(X_train,y_train)

#Predict the response for test dataset
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5868263473053892
